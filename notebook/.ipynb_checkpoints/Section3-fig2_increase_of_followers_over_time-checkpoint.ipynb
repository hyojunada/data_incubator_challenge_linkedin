# %%
import numpy as np
import pandas as pd
import glob
from os.path import splitext, basename
import matplotlib.pyplot as plt

# %% [markdown]
# # df

# %%
df = pd.read_csv('../data/section_3/temp_datalab_records_linkedin_company.csv')
df['as_of_date'] = pd.to_datetime(df.as_of_date)
# Out:
# /anaconda3/envs/tdi/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
def replace_and(x):
    """
    if & or &amp; in value, replace it with /
    """
    if '&'

# %%
df.head()
# Out:
#    dataset_id  as_of_date            company_name  followers_count  \
# 0       58329  2015-09-14           Goldman Sachs           552254
# 1       58329  2015-09-15           Goldman Sachs           552862
# 2       58363  2015-09-16     United Technologies            59157
# 3       58366  2015-09-16            Novo Nordisk           336175
# 4       58371  2015-09-16  Lowe's Companies, Inc.           134255
#
#    employees_on_platform                                   link  \
# 0                  38124  https://www.linkedin.com/company/1382
# 1                  38141  https://www.linkedin.com/company/1382
# 2                  14982  https://www.linkedin.com/company/2426
# 3                  26448  https://www.linkedin.com/company/2227
# 4                  62574  https://www.linkedin.com/company/4128
#
#                industry              date_added            date_updated  \
# 0    Investment Banking  2015-09-14 00:00:00+00  2015-09-14 00:00:00+00
# ...

# %% [markdown]
# # Run

# %%
df_test = df[df.industry == 'Investment Banking']

# %%
df_test.head()
# Out:
#      dataset_id as_of_date   company_name  followers_count  \
# 0         58329 2015-09-14  Goldman Sachs           552254
# 1         58329 2015-09-15  Goldman Sachs           552862
# 65        58329 2015-09-16  Goldman Sachs           553592
# 242       58609 2015-09-17  Deutsche Bank           416329
# 280       58329 2015-09-17  Goldman Sachs           554209
#
#      employees_on_platform                                   link  \
# 0                    38124  https://www.linkedin.com/company/1382
# 1                    38141  https://www.linkedin.com/company/1382
# 65                   38145  https://www.linkedin.com/company/1382
# 242                  51566  https://www.linkedin.com/company/1262
# 280                  38143  https://www.linkedin.com/company/1382
#
#                industry              date_added            date_updated  \
# 0    Investment Banking  2015-09-14 00:00:00+00  2015-09-14 00:00:00+00
# ...

# %%
fig, ax = plt.subplots(figsize=(10,6))
for c, data in df_test.groupby('company_name'):
    ax.scatter(x=data.as_of_date, y=data.followers_count/data.employees_on_platform, label=c)
ax.legend()

# %%
fig, ax = plt.subplots(figsize=(10,6))
for c, data in df.groupby('industry'):
    ax.scatter(x=data.as_of_date, y=data.followers_count/data.employees_on_platform, label=c)
ax.legend()

# %%
for c, data in df.groupby('industry'):
    if (data.followers_count/data.employees_on_platform).mean() > 40000:
        print(c)
# Out:
# Accounting
# Automotive
# Aviation & Aerospace
# Banking
# Biotechnology
# Broadcast Media
# Capital Markets
# Chemicals
# Computer Software
# Consumer Services
# E-Learning
# Electrical/Electronic Manufacturing
# Entertainment
# Financial Services
# Food Production
# Glass, Ceramics & Concrete
# Graphic Design
# Hospital & Health Care
# Hospitality
# Human Resources
# Industrial Automation
# Information Services
# Information Technology and Services
# Insurance
# Internet
# Investment Banking
# Law Practice
# Machinery
# Maritime
# Marketing and Advertising
# Mechanical or Industrial Engineering
# Medical Devices
# Mining & Metals
# Oil & Energy
# Photography
# Real Estate
# Renewables & Environment
# Retail
# Security and Investigations
# Semiconductors
# Staffing and Recruiting
# Telecommunications
# Utilities
# Wholesale

# %%
for i in df.industry.unique():
    try:
        if 'Gambl' in i:
            print(i)
    except TypeError:
        print('Error', i)
# Out:
# Gambling & Casinos
# Error nan
# Gambling &amp; Casinos

# %%
string = 'Gambling &amp; Casinos'

# %%
line.replace('&','&amp;')
