# %%
import pandas as pd

# %%
filename = '/Users/adalee/Downloads/temp_datalab_records_job_listings.csv'

# %%
df = pd.read_csv(filename, nrows=100)

# %%
df
# Out:
#     dataset_id                                         listing_id  \
# 0        57644  https://careers-asburyauto.icims.com/jobs/1538...
# 1      2334936  http://jobs.jcp.com/jobs/2540326-window-commis...
# 2        57644  https://careers-asburyauto.icims.com/jobs/1486...
# 3      2335348  https://sci.jobs/york-pa/maintenance-worker/13...
# 4        57644  https://careers-asburyauto.icims.com/jobs/1542...
# 5      2334936  http://jobs.jcp.com/jobs/2532832-cashier-eden-...
# 6        57644  https://careers-asburyauto.icims.com/jobs/1550...
# 7      2334936  http://jobs.jcp.com/jobs/2534988-operations-as...
# 8        57644  https://careers-asburyauto.icims.com/jobs/1559...
# 9      2334936  http://jobs.jcp.com/jobs/2534512-window-commis...
# 10       57644  https://careers-asburyauto.icims.com/jobs/1553...
# 11     2334936  http://jobs.jcp.com/jobs/2532934-operations-as...
# 12       57644  https://careers-asburyauto.icims.com/jobs/1527...
# ...

# %%
for i in df.columns:
    print('{}: {}'.format(i, df.iloc[20][i]))
# Out:
# dataset_id: 57644
# listing_id: https://careers-asburyauto.icims.com/jobs/15505/slug/job?in_iframe=1
# domain: careers-asburyauto.icims.com
# as_of_date: 2018-05-01
# title: Service Porter / Service Valet / Nalley Ford
# url: https://careers-asburyauto.icims.com/jobs/15505/slug/job?in_iframe=1
# brand: Asbury Automotive Group
# category: nan
# locality: Atlanta
# region: GA
# country: USA
# number_of_openings: nan
# date_added: 2018-05-01 02:15:18.846892+00
# date_updated: 2018-05-01 02:15:18.846907+00
# posted_date: 2018-04-23
# location_string: Atlanta, GA, US
# description: nan
# entity_id: nan
# city_lat: nan
# city_lng: nan
# cusip: nan
# isin: nan
